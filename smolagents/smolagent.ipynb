# %%
pip install smolagents
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["HF_TOKEN"] ="hf_cjkAOKuvxBbynVaiPUAWGBBvQ"

# %%
#from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiMode
from smolagents import CodeAgent, DuckDuckGoSearchTool,TransformersModel

# %%
# !pip install duckduckgo-search
# !pip install smolagents[transformers]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
# ...

# %%
model = TransformersModel()
agent = CodeAgent(tools=[DuckDuckGoSearchTool()],model=model)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\smolagents\models.py:913, in TransformersModel.__init__(self, model_id, device_map, torch_dtype, trust_remote_code, model_kwargs, max_new_tokens, max_tokens, **kwargs)
#     912 try:
# --> 913     self.model = AutoModelForImageTextToText.from_pretrained(
#     914         model_id,
#     915         device_map=device_map,
#     916         torch_dtype=torch_dtype,
#     917         trust_remote_code=trust_remote_code,
#     918         **self.model_kwargs,
#     919     )
# ...

# %%
pip install huggingface_hub[hf_xet]
pip install hf_xet

# %%
from smolagents import CodeAgent, VisitWebpageTool, TransformersModel
agent = CodeAgent(
tools = [VisitWebpageTool()],
model=TransformersModel(),
additional_authorized_imports=["requests", "markdownify"],
use_e2b_executor=True
)

agent.run("What was Abraham Lincoln's preferred pet?")
# Out:
# C:\Users\Saloni\AppData\Roaming\Python\Python313\site-packages\smolagents\models.py:897: FutureWarning: The 'model_id' parameter will be required in version 2.0.0. Please update your code to pass this parameter to avoid future errors. For now, it defaults to 'HuggingFaceTB/SmolLM2-1.7B-Instruct'.
#   warnings.warn(
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\smolagents\models.py:913, in TransformersModel.__init__(self, model_id, device_map, torch_dtype, trust_remote_code, model_kwargs, max_new_tokens, max_tokens, **kwargs)
#     912 try:
# ...

# %%
agent.run('differential human brian & machine brian')
